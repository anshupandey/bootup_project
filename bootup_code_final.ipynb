# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/bootup_project/blob/master/bootup_code_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title BootUP Assessment Analytics
#@markdown * Please enter replace 0 by name of file for the Subject you wish to create a report.
#@markdown * Make sure you have uploaded all the files
#@markdown * The Subjects you do not wish to include, leave the value as 0

basic_python = 'basic_python.xlsx' #@param {type: "string"}
advance_python = 'advance_python.xlsx' #@param {type: "string"}
basic_ds = 'basic_ds.xlsx' #@param {type: "string"}
advance_ds = 'advance_ds.xlsx' #@param {type: "string"}
basic_ml = 'basic_ml.xlsx' #@param {type: "string"}
advance_ml = 'advance_ml.xlsx' #@param {type: "string"}
deep_learning = 'deep_learning.xlsx' #@param {type: "string"}
natural_language_processing = 'natural_language_processing.xlsx' #@param {type: "string"}
big_data_analytics =  '0' #@param {type: "string"}
r_prog =  '0' #@param {type: "string"}

# %%
# %%capture
# !wget https://raw.githubusercontent.com/anshupandey/bootup_project/master/bootup_plot.py
# !wget https://raw.githubusercontent.com/anshupandey/bootup_project/master/main.py

# %%
all_subjects = [basic_python,advance_python,basic_ds,advance_ds,basic_ml,advance_ml,deep_learning,natural_language_processing,big_data_analytics,r_prog]

# %%
import main
main.main(all_subjects)
# Out:
# ['basic_python', 'advance_python', 'basic_ds', 'advance_ds', 'basic_ml', 'advance_ml', 'deep_learning', 'natural_language_processing']
# Processing Visualization for Current Subjects -
# basic_python.xlsx
# advance_python.xlsx
# basic_ds.xlsx
# advance_ds.xlsx
# basic_ml.xlsx
# advance_ml.xlsx
# deep_learning.xlsx
# natural_language_processing.xlsx
# loaded data , loaded data for 22 candidates and showing top 5 rows here
#                Email address  ... natural_language_processing
# 0    oka.uliandana@gmail.com  ...                          18
# 1  emmy.trisnawati@gmail.com  ...                          14
# 2       albariqi@codex.works  ...                          22
# 3         alden@arkademy.com  ...                          20
# 4     hafizjoundys@gmail.com  ...                           8
#
# [5 rows x 10 columns]
# ...
#
#
# ********************
#
# barplot of each candidate with their scores
# ['basic_python', 'basic_ds', 'basic_ml']
# ...

# %%
# %%capture
# !zip -r Employee_graphs.zip Employee_graphs
# !zip -r Final_Graphs.zip Final_Graphs

# %%
from google.colab import files
files.download("Final_Graphs.zip")
files.download("Employee_graphs.zip")
